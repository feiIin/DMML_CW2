# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
import pandas_ml as pdml
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Reading in the data

# %%
x_train_gr_smpl = pd.read_csv("x_train_normalised_with_y_train_smpl.csv", delimiter=",")
x_test_data = pd.read_csv("x_test_normalised_with_y_test_smpl.csv", delimiter=",")

# %%
x_test = x_test_data.iloc[:, 0:1600]
y_test = x_test_data.iloc[:,-1].astype(int)

# %%
x = x_train_gr_smpl.iloc[:, 0:1600]
y = x_train_gr_smpl.iloc[:,-1].astype(int)
X_train, X_test_from_train,  y_train,  y_test_from_train = train_test_split(x, y, test_size=.33, random_state=17)

# %%
def printReports(nn):
    nn.fit(X_train,y_train)
    y_train_pred=cross_val_predict(nn,X_test_from_train,y_test_from_train,cv=10)
    print("Results using train set")
    print(nn.score(X_train, y_train))
    print("\n")
    print("Confusion matrix from ten cross validation:") 
    print(confusion_matrix(y_test_from_train, y_train_pred))
    print("\n")
    print("Classification report")
    print(classification_report(y_test_from_train, y_train_pred))
    print("\nUsing test set ------------------------------------------------------------")
    print("Results using test set:") 
    print(nn.score(x_test,y_test))
    y_test_pred=nn.predict(x_test)
    print("\n")
    print("Confusion matrix using test set:") 
    print(confusion_matrix(y_test, y_test_pred))
    print("\nClassification report:")
    print(classification_report(y_test, y_test_pred))
    print("Metrics =======================================================================")
    cm = pdml.ConfusionMatrix(y_test, y_train_pred)
    stats = cm.stats()
    print(stats)

# %%
nn = MLPClassifier(hidden_layer_sizes=(1,), activation='relu', 
                   momentum=0.9,learning_rate_init=0.001,max_iter=200)

# %%
nn.fit(X_train,y_train)
y_train_pred=cross_val_predict(nn,X_test_from_train,y_test_from_train,cv=10)
print("Results using train set")
print(nn.score(X_train, y_train))
print("\n")
print("Confusion matrix from ten cross validation:") 
print(confusion_matrix(y_test_from_train, y_train_pred))
print("\n")
print("Classification report")
print(classification_report(y_test_from_train, y_train_pred))
print("\nUsing test set ------------------------------------------------------------")
print("Results using test set:") 
print(nn.score(x_test,y_test))
y_test_pred=nn.predict(x_test)
print("\n")
print("Confusion matrix using test set:") 
print(confusion_matrix(y_test, y_test_pred))
print("\nClassification report:")
print(classification_report(y_test, y_test_pred))
print("Metrics =======================================================================")
# Out:
# Results using train set
# 0.16729544918651262
#
#
# Confusion matrix from ten cross validation:
# [[ 15 122   0   3  71 196   0   0  40   0]
#  [  9 156   0   4 139 258   0   0  38   0]
#  [  0  27   0  11  40  56   0   0   6   0]
#  [  1  84   0  61  78 208   0   0  22   0]
#  [  1  67   0  21 285 296   0   0  19   0]
#  [  6   6   0   0   8 690   0   0  31   0]
#  [  3  27   0   4  25 125   0   0  55   0]
#  [  0  17   0   7  22  33   0   0   5   0]
#  [  6   7   0   0   2 487   0   0 202   0]
#  [  0  19   0   1  13  34   0   0   9   0]]
#
#
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.37      0.03      0.06       447
#            1       0.29      0.26      0.27       604
#            2       0.00      0.00      0.00       140
#            3       0.54      0.13      0.22       454
#            4       0.42      0.41      0.42       689
#            5       0.29      0.93      0.44       741
#            6       0.00      0.00      0.00       239
#            7       0.00      0.00      0.00        84
#            8       0.47      0.29      0.36       704
#            9       0.00      0.00      0.00        76
#
#    micro avg       0.34      0.34      0.34      4178
#    macro avg       0.24      0.21      0.18      4178
# weighted avg       0.34      0.34      0.28      4178
#
#
# Using test set ------------------------------------------------------------
# Results using test set:
# 0.17266187050359713
#
#
# Confusion matrix using test set:
# [[  0   0   0   0   0 450   0   0   0   0]
#  [  0   0   0   0   0 630   0   0   0   0]
#  [  0   0   0   0   0 150   0   0   0   0]
#  [  0   0   0   0   0 420   0   0   0   0]
#  [  0   0   0   0   0 690   0   0   0   0]
#  [  0   0   0   0   0 720   0   0   0   0]
#  [  0   0   0   0   0 270   0   0   0   0]
#  [  0   0   0   0   0  60   0   0   0   0]
#  [  0   0   0   0   0 690   0   0   0   0]
#  [  0   0   0   0   0  90   0   0   0   0]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       450
#            1       0.00      0.00      0.00       630
#            2       0.00      0.00      0.00       150
#            3       0.00      0.00      0.00       420
#            4       0.00      0.00      0.00       690
#            5       0.17      1.00      0.29       720
#            6       0.00      0.00      0.00       270
#            7       0.00      0.00      0.00        60
#            8       0.00      0.00      0.00       690
#            9       0.00      0.00      0.00        90
#
#    micro avg       0.17      0.17      0.17      4170
#    macro avg       0.02      0.10      0.03      4170
# weighted avg       0.03      0.17      0.05      4170
#
# Metrics =======================================================================

# %%
cm = pdml.ConfusionMatrix(y_test, y_test_pred)
stats = cm.stats()

# %%
stats['class']
# Out:
# Classes                                       0         1          2  \
# Population                                 4170      4170       4170
# P: Condition positive                       450       630        150
# N: Condition negative                      3720      3540       4020
# Test outcome positive                         0         0          0
# Test outcome negative                      4170      4170       4170
# TP: True Positive                             0         0          0
# TN: True Negative                          3720      3540       4020
# FP: False Positive                            0         0          0
# FN: False Negative                          450       630        150
# TPR: (Sensitivity, hit rate, recall)          0         0          0
# TNR=SPC: (Specificity)                        1         1          1
# PPV: Pos Pred Value (Precision)             NaN       NaN        NaN
# NPV: Neg Pred Value                    0.892086  0.848921   0.964029
# FPR: False-out                                0         0          0
# FDR: False Discovery Rate                   NaN       NaN        NaN
# FNR: Miss Rate                                1         1          1
# ACC: Accuracy                          0.892086  0.848921   0.964029
# F1 score                                      0         0          0
# MCC: Matthews correlation coefficient       NaN       NaN        NaN
# Informedness                                  0         0          0
# Markedness                                  NaN       NaN        NaN
# Prevalence                             0.107914  0.151079  0.0359712
# LR+: Positive likelihood ratio              NaN       NaN        NaN
# LR-: Negative likelihood ratio                1         1          1
# DOR: Diagnostic odds ratio                  NaN       NaN        NaN
# FOR: False omission rate               0.107914  0.151079  0.0359712
#
# Classes                                       3         4         5  \
# Population                                 4170      4170      4170
# P: Condition positive                       420       690       720
# N: Condition negative                      3750      3480      3450
# Test outcome positive                         0         0      4170
# Test outcome negative                      4170      4170         0
# TP: True Positive                             0         0       720
# TN: True Negative                          3750      3480         0
# FP: False Positive                            0         0      3450
# FN: False Negative                          420       690         0
# TPR: (Sensitivity, hit rate, recall)          0         0         1
# TNR=SPC: (Specificity)                        1         1         0
# PPV: Pos Pred Value (Precision)             NaN       NaN  0.172662
# NPV: Neg Pred Value                    0.899281  0.834532       NaN
# FPR: False-out                                0         0         1
# FDR: False Discovery Rate                   NaN       NaN  0.827338
# FNR: Miss Rate                                1         1         0
# ACC: Accuracy                          0.899281  0.834532  0.172662
# F1 score                                      0         0  0.294479
# MCC: Matthews correlation coefficient       NaN       NaN       NaN
# Informedness                                  0         0         0
# Markedness                                  NaN       NaN       NaN
# Prevalence                             0.100719  0.165468  0.172662
# LR+: Positive likelihood ratio              NaN       NaN         1
# LR-: Negative likelihood ratio                1         1       NaN
# DOR: Diagnostic odds ratio                  NaN       NaN       NaN
# FOR: False omission rate               0.100719  0.165468       NaN
#
# Classes                                        6          7         8  \
# Population                                  4170       4170      4170
# P: Condition positive                        270         60       690
# N: Condition negative                       3900       4110      3480
# Test outcome positive                          0          0         0
# Test outcome negative                       4170       4170      4170
# TP: True Positive                              0          0         0
# TN: True Negative                           3900       4110      3480
# FP: False Positive                             0          0         0
# FN: False Negative                           270         60       690
# TPR: (Sensitivity, hit rate, recall)           0          0         0
# TNR=SPC: (Specificity)                         1          1         1
# PPV: Pos Pred Value (Precision)              NaN        NaN       NaN
# NPV: Neg Pred Value                     0.935252   0.985612  0.834532
# FPR: False-out                                 0          0         0
# FDR: False Discovery Rate                    NaN        NaN       NaN
# FNR: Miss Rate                                 1          1         1
# ACC: Accuracy                           0.935252   0.985612  0.834532
# F1 score                                       0          0         0
# MCC: Matthews correlation coefficient        NaN        NaN       NaN
# Informedness                                   0          0         0
# Markedness                                   NaN        NaN       NaN
# Prevalence                             0.0647482  0.0143885  0.165468
# LR+: Positive likelihood ratio               NaN        NaN       NaN
# LR-: Negative likelihood ratio                 1          1         1
# DOR: Diagnostic odds ratio                   NaN        NaN       NaN
# FOR: False omission rate               0.0647482  0.0143885  0.165468
#
# Classes                                        9
# Population                                  4170
# P: Condition positive                         90
# N: Condition negative                       4080
# Test outcome positive                          0
# Test outcome negative                       4170
# TP: True Positive                              0
# TN: True Negative                           4080
# FP: False Positive                             0
# FN: False Negative                            90
# TPR: (Sensitivity, hit rate, recall)           0
# TNR=SPC: (Specificity)                         1
# PPV: Pos Pred Value (Precision)              NaN
# NPV: Neg Pred Value                     0.978417
# FPR: False-out                                 0
# FDR: False Discovery Rate                    NaN
# FNR: Miss Rate                                 1
# ACC: Accuracy                           0.978417
# F1 score                                       0
# MCC: Matthews correlation coefficient        NaN
# Informedness                                   0
# Markedness                                   NaN
# Prevalence                             0.0215827
# LR+: Positive likelihood ratio               NaN
# LR-: Negative likelihood ratio                 1
# DOR: Diagnostic odds ratio                   NaN
# FOR: False omission rate               0.0215827

# %%
stats['class'].loc['TP: True Positive'].mean()
# Out:
# 72.0

# %%
stats['class'].loc['FP: False Positive'].mean()
# Out:
# 345.0

# %%
#Recall
stats['class'].loc['TPR: (Sensitivity, hit rate, recall)'].mean()
# Out:
# 0.1

# %%
stats['class'].loc['F1 score'].mean()
# Out:
# 0.0294478527607362

# %%
from sklearn.metrics import roc_auc_score
from sklearn import preprocessing

# %%
lb = preprocessing.LabelBinarizer()
lb.fit(y_test)
y_test_b = lb.transform(y_test)
y_test_pred_b = lb.transform(y_test_pred)
roc_auc_score(y_test_b, y_test_pred_b, average=None).mean()
# Out:
# 0.5
