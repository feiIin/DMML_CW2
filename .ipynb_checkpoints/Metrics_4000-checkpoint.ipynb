# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
import pandas_ml as pdml
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Reading in the data

# %%
x_train_gr_smpl = pd.read_csv("./new_4000_all_classes/x_train_4000_with_y_train_smpl.csv", delimiter=",")
x_test_data = pd.read_csv("./new_4000_all_classes/x_test_4000_with_y_test_smpl.csv", delimiter=",")

# %%
x_test = x_test_data.iloc[:, 0:1600]
y_test = x_test_data.iloc[:,-1].astype(int)

# %%
x = x_train_gr_smpl.iloc[:, 0:1600]
y = x_train_gr_smpl.iloc[:,-1].astype(int)
X_train, X_test_from_train,  y_train,  y_test_from_train = train_test_split(x, y, test_size=.33, random_state=17)

# %%
def printReports(nn):
    nn.fit(X_train,y_train)
    y_train_pred=cross_val_predict(nn,X_test_from_train,y_test_from_train,cv=10)
    print("Results using train set")
    print(nn.score(X_train, y_train))
    print("\n")
    print("Confusion matrix from ten cross validation:") 
    print(confusion_matrix(y_test_from_train, y_train_pred))
    print("\n")
    print("Classification report")
    print(classification_report(y_test_from_train, y_train_pred))
    print("\nUsing test set ------------------------------------------------------------")
    print("Results using test set:") 
    print(nn.score(x_test,y_test))
    y_test_pred=nn.predict(x_test)
    print("\n")
    print("Confusion matrix using test set:") 
    print(confusion_matrix(y_test, y_test_pred))
    print("\nClassification report:")
    print(classification_report(y_test, y_test_pred))
    print("Metrics =======================================================================")
    cm = pdml.ConfusionMatrix(y_test, y_train_pred)
    stats = cm.stats()
    print(stats)

# %%
nn = MLPClassifier(hidden_layer_sizes=(20,), activation='relu', 
                   momentum=0.9,learning_rate_init=0.001,max_iter=200)

# %%
nn.fit(X_train,y_train)
y_train_pred=cross_val_predict(nn,X_test_from_train,y_test_from_train,cv=10)
print("Results using train set")
print(nn.score(X_train, y_train))
print("\n")
print("Confusion matrix from ten cross validation:") 
print(confusion_matrix(y_test_from_train, y_train_pred))
print("\n")
print("Classification report")
print(classification_report(y_test_from_train, y_train_pred))
print("\nUsing test set ------------------------------------------------------------")
print("Results using test set:") 
print(nn.score(x_test,y_test))
y_test_pred=nn.predict(x_test)
print("\n")
print("Confusion matrix using test set:") 
print(confusion_matrix(y_test, y_test_pred))
print("\nClassification report:")
print(classification_report(y_test, y_test_pred))
print("Metrics =======================================================================")
# Out:
# Results using train set
# 0.9350112049646613
#
#
# Confusion matrix from ten cross validation:
# [[201  86   0   0   4   4   0   0   9   0]
#  [ 49 366   0   3   2   3   0   0   9   0]
#  [  1   2  97   0   5   0   0   4   0   0]
#  [  1   5   0 284  10   0   0   0   1   0]
#  [  3  13   1   7 456   4   0   1   7   0]
#  [  3   2   0   0  10 437   0   0   3   0]
#  [  0   1   0   0   1   0 163   0   4   0]
#  [  7   1  21   1   7   1   0  12   2   0]
#  [  7   4   0   0   8   1   0   0 459   0]
#  [  0   5   1   1   4   0   0   0   0  54]]
#
#
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.74      0.66      0.70       304
#            1       0.75      0.85      0.80       432
#            2       0.81      0.89      0.85       109
#            3       0.96      0.94      0.95       301
#            4       0.90      0.93      0.91       492
#            5       0.97      0.96      0.97       455
#            6       1.00      0.96      0.98       169
#            7       0.71      0.23      0.35        52
#            8       0.93      0.96      0.94       479
#            9       1.00      0.83      0.91        65
#
#    micro avg       0.88      0.88      0.88      2858
#    macro avg       0.88      0.82      0.84      2858
# weighted avg       0.88      0.88      0.88      2858
#
#
# Using test set ------------------------------------------------------------
# Results using test set:
# 0.9085679314565483
#
#
# Confusion matrix using test set:
# [[ 658  198    1    1    9    7    1    2   19    0]
#  [ 103 1070    0    5   20    7    0    1   21    0]
#  [  32    3  218    0    3    0    0   11    2    0]
#  [   0    6    0  784   40    2    0    0    3    3]
#  [   6   22    1   15 1297   16    0    0    6    0]
#  [   0    1    0    1   10 1389    0    0   11    2]
#  [   9    1    0    1    4    0  492    0    5    0]
#  [   8    0   23    0   35    2    0   69    4    0]
#  [   8    6    0    1   14    8   20    0 1275    0]
#  [   0    0    0    2    4    1    0    0    0  171]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.73      0.77       896
#            1       0.82      0.87      0.84      1227
#            2       0.90      0.81      0.85       269
#            3       0.97      0.94      0.95       838
#            4       0.90      0.95      0.93      1363
#            5       0.97      0.98      0.98      1414
#            6       0.96      0.96      0.96       512
#            7       0.83      0.49      0.62       141
#            8       0.95      0.96      0.95      1332
#            9       0.97      0.96      0.97       178
#
#    micro avg       0.91      0.91      0.91      8170
#    macro avg       0.91      0.87      0.88      8170
# weighted avg       0.91      0.91      0.91      8170
#
# Metrics =======================================================================

# %%
cm = pdml.ConfusionMatrix(y_test, y_test_pred)
stats = cm.stats()

# %%
stats['class']
# Out:
# Classes                                        0          1           2  \
# Population                                  8170       8170        8170
# P: Condition positive                        896       1227         269
# N: Condition negative                       7274       6943        7901
# Test outcome positive                        824       1307         243
# Test outcome negative                       7346       6863        7927
# TP: True Positive                            658       1070         218
# TN: True Negative                           7108       6706        7876
# FP: False Positive                           166        237          25
# FN: False Negative                           238        157          51
# TPR: (Sensitivity, hit rate, recall)    0.734375   0.872046    0.810409
# TNR=SPC: (Specificity)                  0.977179   0.965865    0.996836
# PPV: Pos Pred Value (Precision)         0.798544   0.818669    0.897119
# NPV: Neg Pred Value                     0.967601   0.977124    0.993566
# FPR: False-out                          0.022821  0.0341351  0.00316416
# FDR: False Discovery Rate               0.201456   0.181331    0.102881
# FNR: Miss Rate                          0.265625   0.127954    0.189591
# ACC: Accuracy                           0.950551   0.951775    0.990698
# F1 score                                0.765116   0.844515    0.851562
# MCC: Matthews correlation coefficient   0.738345    0.81658    0.847939
# Informedness                            0.711554   0.837911    0.807245
# Markedness                              0.766145   0.795792    0.890686
# Prevalence                               0.10967   0.150184   0.0329253
# LR+: Positive likelihood ratio           32.1798    25.5469     256.122
# LR-: Negative likelihood ratio          0.271828   0.132476    0.190193
# DOR: Diagnostic odds ratio               118.383    192.841     1346.64
# FOR: False omission rate               0.0323986  0.0228763  0.00643371
#
# Classes                                         3           4           5  \
# Population                                   8170        8170        8170
# P: Condition positive                         838        1363        1414
# N: Condition negative                        7332        6807        6756
# Test outcome positive                         810        1436        1432
# Test outcome negative                        7360        6734        6738
# TP: True Positive                             784        1297        1389
# TN: True Negative                            7306        6668        6713
# FP: False Positive                             26         139          43
# FN: False Negative                             54          66          25
# TPR: (Sensitivity, hit rate, recall)     0.935561    0.951577     0.98232
# TNR=SPC: (Specificity)                   0.996454     0.97958    0.993635
# PPV: Pos Pred Value (Precision)          0.967901    0.903203    0.969972
# NPV: Neg Pred Value                      0.992663    0.990199     0.99629
# FPR: False-out                          0.0035461   0.0204202  0.00636471
# FDR: False Discovery Rate               0.0320988   0.0967967   0.0300279
# FNR: Miss Rate                          0.0644391   0.0484226   0.0176803
# ACC: Accuracy                            0.990208    0.974908    0.991677
# F1 score                                 0.951456     0.92676    0.976107
# MCC: Matthews correlation coefficient    0.946182    0.912084    0.971096
# Informedness                             0.932015    0.931157    0.975955
# Markedness                               0.960564    0.893402    0.966262
# Prevalence                                0.10257     0.16683    0.173072
# LR+: Positive likelihood ratio            263.828     46.5999     154.338
# LR-: Negative likelihood ratio          0.0646685    0.049432   0.0177936
# DOR: Diagnostic odds ratio                 4079.7     942.707     8673.82
# FOR: False omission rate               0.00733696  0.00980101   0.0037103
#
# Classes                                         6           7           8  \
# Population                                   8170        8170        8170
# P: Condition positive                         512         141        1332
# N: Condition negative                        7658        8029        6838
# Test outcome positive                         513          83        1346
# Test outcome negative                        7657        8087        6824
# TP: True Positive                             492          69        1275
# TN: True Negative                            7637        8015        6767
# FP: False Positive                             21          14          71
# FN: False Negative                             20          72          57
# TPR: (Sensitivity, hit rate, recall)     0.960938    0.489362    0.957207
# TNR=SPC: (Specificity)                   0.997258    0.998256    0.989617
# PPV: Pos Pred Value (Precision)          0.959064    0.831325    0.947251
# NPV: Neg Pred Value                      0.997388    0.991097    0.991647
# FPR: False-out                         0.00274223  0.00174368   0.0103832
# FDR: False Discovery Rate               0.0409357    0.168675   0.0527489
# FNR: Miss Rate                          0.0390625    0.510638   0.0427928
# ACC: Accuracy                            0.994982    0.989474    0.984333
# F1 score                                     0.96    0.616071    0.952203
# MCC: Matthews correlation coefficient    0.957323    0.633268    0.942853
# Informedness                             0.958195    0.487618    0.946824
# Markedness                               0.956452    0.822422    0.938898
# Prevalence                              0.0626683   0.0172583    0.163035
# LR+: Positive likelihood ratio            350.422     280.649     92.1885
# LR-: Negative likelihood ratio          0.0391699     0.51153   0.0432418
# DOR: Diagnostic odds ratio                 8946.2     548.646     2131.93
# FOR: False omission rate               0.00261199  0.00890318  0.00835287
#
# Classes                                          9
# Population                                    8170
# P: Condition positive                          178
# N: Condition negative                         7992
# Test outcome positive                          176
# Test outcome negative                         7994
# TP: True Positive                              171
# TN: True Negative                             7987
# FP: False Positive                               5
# FN: False Negative                               7
# TPR: (Sensitivity, hit rate, recall)      0.960674
# TNR=SPC: (Specificity)                    0.999374
# PPV: Pos Pred Value (Precision)           0.971591
# NPV: Neg Pred Value                       0.999124
# FPR: False-out                         0.000625626
# FDR: False Discovery Rate                0.0284091
# FNR: Miss Rate                           0.0393258
# ACC: Accuracy                             0.998531
# F1 score                                  0.966102
# MCC: Matthews correlation coefficient     0.965367
# Informedness                              0.960049
# Markedness                                0.970715
# Prevalence                                0.021787
# LR+: Positive likelihood ratio             1535.54
# LR-: Negative likelihood ratio           0.0393505
# DOR: Diagnostic odds ratio                 39022.2
# FOR: False omission rate               0.000875657

# %%
stats['class'].loc['TP: True Positive'].mean()
# Out:
# 742.3

# %%
stats['class'].loc['FP: False Positive'].mean()
# Out:
# 74.7

# %%
#Recall
stats['class'].loc['TPR: (Sensitivity, hit rate, recall)'].mean()
# Out:
# 0.8654468050857119

# %%
stats['class'].loc['F1 score'].mean()
# Out:
# 0.8809892324895214

# %%
from sklearn.metrics import roc_auc_score
from sklearn import preprocessing

# %%
lb = preprocessing.LabelBinarizer()
lb.fit(y_test)
y_test_b = lb.transform(y_test)
y_test_pred_b = lb.transform(y_test_pred)
print(f"ROC Area: {roc_auc_score(y_test_b, y_test_pred_b, average=None).mean()}")
# Out:
# ROC Area: 0.9274261066015566
